# %%
data="""ArithmeticErrorMachine learning is a field of artificial intelligence.
Machine learning helps computers learn from data.
Data is the foundation of machine learning.
Python is a popular language for data science.
Data scientists use Python for analysis and modeling.
Deep learning is a subset of machine learning.
Neural networks are inspired by the human brain.
Artificial intelligence is changing the world.
Students learn programming to solve problems.
Programming requires logic and practice.
Practice makes a programmer better every day.
Python supports many machine learning libraries.
TensorFlow is a popular deep learning framework.
Keras makes building neural networks easier.
Data preprocessing is an important step in machine learning.
Cleaning data improves model performance.
Feature engineering helps models learn better patterns.
Models learn from historical data.
Training data is used to fit a model.
Testing data is used to evaluate a model.
LSTM networks are useful for sequence prediction.
Recurrent neural networks process sequential data.
Text data contains words and sentences.
Natural language processing helps computers understand text.
Tokenization converts text into tokens.
Embedding layers convert words into vectors.
Vectors represent the meaning of words.
Words with similar meanings have similar vectors.
Language models predict the next word in a sequence.
Prediction accuracy improves with more training data.
Students study machine learning to build intelligent systems.
Artificial intelligence can automate many tasks.
Data analysis helps organizations make decisions.
Business intelligence uses data to gain insights.
Databases store structured information.
SQL is used to query relational databases.
Data visualization helps communicate findings.
Charts and graphs make data easier to understand.
Pandas is a popular Python library.
NumPy provides support for numerical computing.
Matplotlib is used for plotting graphs.
Scikit learn provides machine learning algorithms.
Classification predicts categorical outcomes.
Regression predicts numerical values.
Clustering groups similar data points.
Decision trees are easy to interpret.
Random forests combine multiple decision trees.
Gradient boosting improves predictive performance.
Neural networks learn complex patterns.
Optimization algorithms adjust model weights.
The loss function measures prediction error.
Backpropagation updates neural network parameters.
Epochs represent complete passes through training data.
Batch size controls the number of samples processed together.
Overfitting occurs when a model memorizes data.
Regularization helps prevent overfitting.
Cross validation improves model evaluation.
Feature selection removes irrelevant variables.
Data quality affects model performance.
Good data leads to better predictions.
Students should practice coding every day.
Consistency is important for learning.
Learning new skills requires patience.
Technology evolves rapidly over time.
Software engineers build useful applications.
Web development uses HTML CSS and JavaScript.
Backend development handles server logic.
Frontend development focuses on user interfaces.
APIs allow applications to communicate.
Cloud computing provides scalable resources.
Cybersecurity protects systems from threats.
Ethical hackers identify security vulnerabilities.
Networking connects computers around the world.
Operating systems manage computer resources.
Linux is widely used on servers.
Version control helps track code changes.
Git is a popular version control system.
GitHub hosts software repositories.
Developers collaborate using GitHub.
Projects improve practical knowledge.
Hands on experience is valuable.
Problem solving is a key engineering skill.
Algorithms provide step by step solutions.
Data structures organize information efficiently.
Arrays store elements in sequence.
Linked lists connect nodes together.
Stacks follow last in first out order.
Queues follow first in first out order.
Trees represent hierarchical structures.
Graphs model relationships between entities.
Searching algorithms locate information quickly.
Sorting algorithms arrange data efficiently.
Binary search is fast on sorted data.
Merge sort uses divide and conquer.
Quick sort is efficient in practice.
Dynamic programming solves complex problems.
Recursion breaks problems into smaller parts.
Computer science combines theory and practice.
Knowledge grows through continuous learning.
Success comes from consistent effort.
Hard work leads to improvement.
Curiosity drives innovation and discovery.
Learning never stops in technology."""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([data])

# %%
len(tokenizer.word_index)
# Out:
# 341

# %%
input_sequence=[]

for sentence in data.split('\n'):
    
    tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]

    for i in range(1,len(tokenized_sentence)):
        input_sequence.append(tokenized_sentence[:i+1])

# %%
input_sequence
# Out:
# [[102, 3],
#  [102, 3, 2],
#  [102, 3, 2, 4],
#  [102, 3, 2, 4, 103],
#  [102, 3, 2, 4, 103, 14],
#  [102, 3, 2, 4, 103, 14, 27],
#  [102, 3, 2, 4, 103, 14, 27, 20],
#  [9, 3],
#  [9, 3, 10],
#  [9, 3, 10, 28],
#  [9, 3, 10, 28, 12],
#  [9, 3, 10, 28, 12, 21],
#  [9, 3, 10, 28, 12, 21, 1],
#  [1, 2],
#  [1, 2, 6],
#  [1, 2, 6, 104],
#  [1, 2, 6, 104, 14],
#  [1, 2, 6, 104, 14, 9],
#  [1, 2, 6, 104, 14, 9, 3],
#  [22, 2],
#  [22, 2, 4],
#  [22, 2, 4, 23],
#  [22, 2, 4, 23, 29],
#  [22, 2, 4, 23, 29, 13],
#  [22, 2, 4, 23, 29, 13, 1],
#  [22, 2, 4, 23, 29, 13, 1, 54],
#  [1, 105],
#  [1, 105, 106],
#  [1, 105, 106, 22],
#  [1, 105, 106, 22, 13],
#  [1, 105, 106, 22, 13, 55],
#  [1, 105, 106, 22, 13, 55, 7],
#  [1, 105, 106, 22, 13, 55, 7, 107],
#  [56, 3],
#  [56, 3, 2],
#  [56, 3, 2, 4],
#  [56, 3, 2, 4, 108],
#  [56, 3, 2, 4, 108, 14],
#  [56, 3, 2, 4, 108, 14, 9],
#  [56, 3, 2, 4, 108, 14, 9, 3],
#  [15, 16],
#  [15, 16, 30],
#  [15, 16, 30, 109],
#  [15, 16, 30, 109, 57],
#  [15, 16, 30, 109, 57, 6],
#  [15, 16, 30, 109, 57, 6, 110],
#  [15, 16, 30, 109, 57, 6, 110, 111],
#  [27, 20],
#  [27, 20, 2],
#  [27, 20, 2, 112],
#  [27, 20, 2, 112, 6],
#  [27, 20, 2, 112, 6, 58],
#  [31, 12],
#  [31, 12, 32],
#  [31, 12, 32, 5],
#  [31, 12, 32, 5, 113],
#  [31, 12, 32, 5, 113, 33],
#  [32, 59],
#  [32, 59, 60],
#  [32, 59, 60, 7],
#  [32, 59, 60, 7, 17],
#  [17, 61],
#  [17, 61, 4],
#  [17, 61, 4, 114],
#  [17, 61, 4, 114, 34],
#  [17, 61, 4, 114, 34, 62],
#  [17, 61, 4, 114, 34, 62, 63],
#  [22, 115],
#  [22, 115, 64],
#  [22, 115, 64, 9],
#  [22, 115, 64, 9, 3],
#  [22, 115, 64, 9, 3, 116],
#  [117, 2],
#  [117, 2, 4],
#  [117, 2, 4, 23],
#  [117, 2, 4, 23, 56],
#  [117, 2, 4, 23, 56, 3],
#  [117, 2, 4, 23, 56, 3, 118],
#  [119, 61],
#  [119, 61, 120],
#  [119, 61, 120, 15],
#  [119, 61, 120, 15, 16],
#  [119, 61, 120, 15, 16, 65],
#  [1, 121],
#  [1, 121, 2],
#  [1, 121, 2, 122],
#  [1, 121, 2, 122, 66],
#  [1, 121, 2, 122, 66, 35],
#  [1, 121, 2, 122, 66, 35, 11],
#  [1, 121, 2, 122, 66, 35, 11, 9],
#  [1, 121, 2, 122, 66, 35, 11, 9, 3],
#  [123, 1],
#  [123, 1, 24],
#  [123, 1, 24, 8],
#  [123, 1, 24, 8, 36],
#  [67, 68],
#  [67, 68, 10],
#  [67, 68, 10, 37],
#  [67, 68, 10, 37, 12],
#  [67, 68, 10, 37, 12, 34],
#  [67, 68, 10, 37, 12, 34, 69],
#  [37, 12],
#  [37, 12, 21],
#  [37, 12, 21, 124],
#  [37, 12, 21, 124, 1],
#  [38, 1],
#  [38, 1, 2],
#  [38, 1, 2, 18],
#  [38, 1, 2, 18, 5],
#  [38, 1, 2, 18, 5, 125],
#  [38, 1, 2, 18, 5, 125, 4],
#  [38, 1, 2, 18, 5, 125, 4, 8],
#  [126, 1],
#  [126, 1, 2],
#  [126, 1, 2, 18],
#  [126, 1, 2, 18, 5],
#  [126, 1, 2, 18, 5, 127],
#  [126, 1, 2, 18, 5, 127, 4],
#  [126, 1, 2, 18, 5, 127, 4, 8],
#  [128, 16],
#  [128, 16, 30],
#  [128, 16, 30, 70],
#  [128, 16, 30, 70, 13],
#  [128, 16, 30, 70, 13, 39],
#  [128, 16, 30, 70, 13, 39, 40],
#  [129, 15],
#  [129, 15, 16],
#  [129, 15, 16, 130],
#  [129, 15, 16, 130, 131],
#  [129, 15, 16, 130, 131, 1],
#  [41, 1],
#  [41, 1, 132],
#  [41, 1, 132, 25],
#  [41, 1, 132, 25, 7],
#  [41, 1, 132, 25, 7, 133],
#  [134, 29],
#  [134, 29, 135],
#  [134, 29, 135, 10],
#  [134, 29, 135, 10, 28],
#  [134, 29, 135, 10, 28, 71],
#  [134, 29, 135, 10, 28, 71, 41],
#  [136, 137],
#  [136, 137, 41],
#  [136, 137, 41, 42],
#  [136, 137, 41, 42, 138],
#  [139, 140],
#  [139, 140, 141],
#  [139, 140, 141, 25],
#  [139, 140, 141, 25, 42],
#  [139, 140, 141, 25, 42, 43],
#  [43, 44],
#  [43, 44, 6],
#  [43, 44, 6, 142],
#  [43, 44, 6, 142, 14],
#  [43, 44, 6, 142, 14, 25],
#  [25, 72],
#  [25, 72, 45],
#  [25, 72, 45, 143],
#  [25, 72, 45, 143, 144],
#  [25, 72, 45, 143, 144, 45],
#  [25, 72, 45, 143, 144, 45, 43],
#  [29, 37],
#  [29, 37, 145],
#  [29, 37, 145, 6],
#  [29, 37, 145, 6, 146],
#  [29, 37, 145, 6, 146, 147],
#  [29, 37, 145, 6, 146, 147, 11],
#  [29, 37, 145, 6, 146, 147, 11, 4],
#  [29, 37, 145, 6, 146, 147, 11, 4, 39],
#  [40, 148],
#  [40, 148, 24],
#  [40, 148, 24, 72],
#  [40, 148, 24, 72, 149],
#  [40, 148, 24, 72, 149, 38],
#  [40, 148, 24, 72, 149, 38, 1],
#  [31, 150],
#  [31, 150, 9],
#  [31, 150, 9, 3],
#  [31, 150, 9, 3, 5],
#  [31, 150, 9, 3, 5, 73],
#  [31, 150, 9, 3, 5, 73, 151],
#  [31, 150, 9, 3, 5, 73, 151, 46],
#  [27, 20],
#  [27, 20, 152],
#  [27, 20, 152, 153],
#  [27, 20, 152, 153, 64],
#  [27, 20, 152, 153, 64, 154],
#  [1, 55],
#  [1, 55, 10],
#  [1, 55, 10, 155],
#  [1, 55, 10, 155, 74],
#  [1, 55, 10, 155, 74, 156],
#  [157, 20],
#  [157, 20, 47],
#  [157, 20, 47, 1],
#  [157, 20, 47, 1, 5],
#  [157, 20, 47, 1, 5, 158],
#  [157, 20, 47, 1, 5, 158, 159],
#  [75, 76],
#  [75, 76, 160],
#  [75, 76, 160, 48],
#  [161, 2],
#  [161, 2, 18],
#  [161, 2, 18, 5],
#  [161, 2, 18, 5, 162],
#  [161, 2, 18, 5, 162, 163],
#  [161, 2, 18, 5, 162, 163, 75],
#  [1, 164],
#  [1, 164, 10],
#  [1, 164, 10, 77],
#  [1, 164, 10, 77, 165],
#  [166, 7],
#  [166, 7, 49],
#  [166, 7, 49, 74],
#  [166, 7, 49, 74, 1],
#  [166, 7, 49, 74, 1, 65],
#  [166, 7, 49, 74, 1, 65, 5],
#  [166, 7, 49, 74, 1, 65, 5, 71],
#  [167, 2],
#  [167, 2, 4],
#  [167, 2, 4, 23],
#  [167, 2, 4, 23, 22],
#  [167, 2, 4, 23, 22, 168],
#  [169, 50],
#  [169, 50, 170],
#  [169, 50, 170, 13],
#  [169, 50, 170, 13, 78],
#  [169, 50, 170, 13, 78, 79],
#  [171, 2],
#  [171, 2, 18],
#  [171, 2, 18, 13],
#  [171, 2, 18, 13, 172],
#  [171, 2, 18, 13, 172, 49],
#  [173, 12],
#  [173, 12, 50],
#  [173, 12, 50, 9],
#  [173, 12, 50, 9, 3],
#  [173, 12, 50, 9, 3, 19],
#  [174, 80],
#  [174, 80, 175],
#  [174, 80, 175, 176],
#  [177, 80],
#  [177, 80, 78],
#  [177, 80, 78, 178],
#  [179, 180],
#  [179, 180, 45],
#  [179, 180, 45, 1],
#  [179, 180, 45, 1, 181],
#  [81, 51],
#  [81, 51, 30],
#  [81, 51, 30, 182],
#  [81, 51, 30, 182, 5],
#  [81, 51, 30, 182, 5, 183],
#  [184, 185],
#  [184, 185, 186],
#  [184, 185, 186, 187],
#  [184, 185, 186, 187, 81],
#  [184, 185, 186, 187, 81, 51],
#  [188, 189],
#  [188, 189, 24],
#  [188, 189, 24, 190],
#  [188, 189, 24, 190, 36],
#  [15, 16],
#  [15, 16, 12],
#  [15, 16, 12, 82],
#  [15, 16, 12, 82, 69],
#  [191, 19],
#  [191, 19, 192],
#  [191, 19, 192, 8],
#  [191, 19, 192, 8, 193],
#  [6, 194],
#  [6, 194, 195],
#  [6, 194, 195, 196],
#  [6, 194, 195, 196, 40],
#  [6, 194, 195, 196, 40, 197],
#  [198, 199],
#  [198, 199, 15],
#  [198, 199, 15, 200],
#  [198, 199, 15, 200, 201],
#  [202, 44],
#  [202, 44, 203],
#  [202, 44, 203, 204],
#  [202, 44, 203, 204, 83],
#  [202, 44, 203, 204, 83, 38],
#  [202, 44, 203, 204, 83, 38, 1],
#  [205, 206],
#  [205, 206, 207],
#  [205, 206, 207, 6],
#  [205, 206, 207, 6, 208],
#  [205, 206, 207, 6, 208, 14],
#  [205, 206, 207, 6, 208, 14, 209],
#  [205, 206, 207, 6, 208, 14, 209, 210],
#  [205, 206, 207, 6, 208, 14, 209, 210, 84],
#  [85, 211],
#  [85, 211, 212],
#  [85, 211, 212, 4],
#  [85, 211, 212, 4, 8],
#  [85, 211, 212, 4, 8, 213],
#  [85, 211, 212, 4, 8, 213, 1],
#  [214, 10],
#  [214, 10, 215],
#  [214, 10, 215, 85],
#  [216, 217],
#  [216, 217, 24],
#  [216, 217, 24, 8],
#  [216, 217, 24, 8, 218],
#  [67, 219],
#  [67, 219, 220],
#  [67, 219, 220, 221],
#  [67, 219, 220, 221, 222],
#  [1, 223],
#  [1, 223, 224],
#  [1, 223, 224, 8],
#  [1, 223, 224, 8, 36],
#  [225, 1],
#  [225, 1, 86],
#  [225, 1, 86, 5],
#  [225, 1, 86, 5, 34],
#  [225, 1, 86, 5, 34, 226],
#  [31, 227],
#  [31, 227, 17],
#  [31, 227, 17, 228],
#  [31, 227, 17, 228, 62],
#  [31, 227, 17, 228, 62, 63],
#  [229, 2],
#  [229, 2, 66],
#  [229, 2, 66, 13],
#  [229, 2, 66, 13, 3],
#  [3, 230],
#  [3, 230, 231],
#  [3, 230, 231, 59],
#  [3, 230, 231, 59, 232],
#  [87, 233],
#  [87, 233, 234],
#  [87, 233, 234, 235],
#  [87, 233, 234, 235, 236],
#  [88, 237],
#  [88, 237, 73],
#  [88, 237, 73, 70],
#  [88, 237, 73, 70, 89],
#  [238, 52],
#  [238, 52, 47],
#  [238, 52, 47, 239],
#  [238, 52, 47, 239, 240],
#  [238, 52, 47, 239, 240, 7],
#  [238, 52, 47, 239, 240, 7, 241],
#  [242, 52],
#  [242, 52, 243],
#  [242, 52, 243, 244],
#  [242, 52, 243, 244, 60],
#  [245, 52],
#  [245, 52, 246],
#  [245, 52, 246, 26],
#  [245, 52, 246, 26, 247],
#  [245, 52, 246, 26, 247, 248],
#  [249, 250],
#  [249, 250, 89],
#  [249, 250, 89, 5],
#  [249, 250, 89, 5, 77],
#  [251, 79],
#  [251, 79, 50],
#  [251, 79, 50, 252],
#  [251, 79, 50, 252, 90],
#  [253, 254],
#  [253, 254, 46],
#  [253, 254, 46, 21],
#  [253, 254, 46, 21, 255],
#  [256, 257],
#  [256, 257, 258],
#  [256, 257, 258, 259],
#  [256, 257, 258, 259, 260],
#  [261, 262],
#  [261, 262, 28],
#  [261, 262, 28, 263],
#  [261, 262, 28, 263, 6],
#  [261, 262, 28, 263, 6, 58],
#  [264, 46],
#  [264, 46, 265],
#  [264, 46, 265, 91],
#  [264, 46, 265, 91, 90],
#  [266, 2],
#  [266, 2, 267],
#  [266, 2, 267, 18],
#  [266, 2, 267, 18, 26],
#  [266, 2, 267, 18, 26, 268],
#  [92, 93],
#  [92, 93, 10],
#  [92, 93, 10, 269],
#  [92, 93, 10, 269, 270],
#  [92, 93, 10, 269, 270, 271],
#  [272, 2],
#  [272, 2, 4],
#  [272, 2, 4, 23],
#  [272, 2, 4, 23, 92],
#  [272, 2, 4, 23, 92, 93],
#  [272, 2, 4, 23, 92, 93, 273],
#  [94, 274],
#  [94, 274, 88],
#  [94, 274, 88, 275],
#  [276, 277],
#  [276, 277, 278],
#  [276, 277, 278, 94],
#  [279, 280],
#  [279, 280, 281],
#  [279, 280, 281, 95],
#  [282, 26],
#  [282, 26, 283],
#  [282, 26, 283, 2],
#  [282, 26, 283, 2, 284],
#  [285, 286],
#  [285, 286, 2],
#  [285, 286, 2, 4],
#  [285, 286, 2, 4, 287],
#  [285, 286, 2, 4, 287, 68],
#  [285, 286, 2, 4, 287, 68, 288],
#  [19, 289],
#  [19, 289, 35],
#  [19, 289, 35, 57],
#  [19, 289, 35, 57, 35],
#  [19, 289, 35, 57, 35, 290],
#  [1, 96],
#  [1, 96, 291],
#  [1, 96, 291, 48],
#  [1, 96, 291, 48, 97],
#  [292, 76],
#  [292, 76, 293],
#  [292, 76, 293, 11],
#  [292, 76, 293, 11, 39],
#  [294, 295],
#  [294, 295, 296],
#  [294, 295, 296, 297],
#  [294, 295, 296, 297, 84],
#  [298, 98],
#  [298, 98, 299],
#  [298, 98, 299, 11],
#  [298, 98, 299, 11, 53],
#  [298, 98, 299, 11, 53, 99],
#  [298, 98, 299, 11, 53, 99, 100],
#  [300, 98],
#  [300, 98, 53],
#  [300, 98, 53, 11],
#  [300, 98, 53, 11, 53],
#  [300, 98, 53, 11, 53, 99],
#  [300, 98, 53, 11, 53, 99, 100],
#  [51, 44],
#  [51, 44, 301],
#  [51, 44, 301, 96],
#  [49, 8],
#  [49, 8, 302],
#  [49, 8, 302, 303],
#  [49, 8, 302, 303, 304],
#  [305, 19],
#  [305, 19, 306],
#  [305, 19, 306, 48],
#  [305, 19, 306, 48, 307],
#  [308, 19],
#  [308, 19, 309],
#  [308, 19, 309, 1],
#  [308, 19, 309, 1, 97],
#  [310, 311],
#  [310, 311, 2],
#  [310, 311, 2, 312],
#  [310, 311, 2, 312, 26],
#  [310, 311, 2, 312, 26, 313],
#  [310, 311, 2, 312, 26, 313, 1],
#  [314, 101],
#  [314, 101, 47],
#  [314, 101, 47, 315],
#  [314, 101, 47, 315, 7],
#  [314, 101, 47, 315, 7, 316],
#  [317, 101],
#  [317, 101, 2],
#  [317, 101, 2, 318],
#  [317, 101, 2, 318, 11],
#  [317, 101, 2, 318, 11, 17],
#  [319, 32],
#  [319, 32, 320],
#  [319, 32, 320, 82],
#  [319, 32, 320, 82, 33],
#  [321, 322],
#  [321, 322, 33],
#  [321, 322, 33, 42],
#  [321, 322, 33, 42, 323],
#  [321, 322, 33, 42, 323, 324],
#  [91, 54],
#  [91, 54, 325],
#  [91, 54, 325, 326],
#  [91, 54, 325, 326, 7],
#  [91, 54, 325, 326, 7, 17],
#  [95, 327],
#  [95, 327, 83],
#  [95, 327, 83, 328],
#  [95, 327, 83, 328, 3],
#  [329, 330],
#  [329, 330, 21],
#  [329, 330, 21, 331],
#  [329, 330, 21, 331, 332],
#  [333, 334],
#  [333, 334, 86],
#  [333, 334, 86, 5],
#  [333, 334, 86, 5, 335],
#  [336, 337],
#  [336, 337, 338],
#  [336, 337, 338, 7],
#  [336, 337, 338, 7, 339],
#  [3, 340],
#  [3, 340, 341],
#  [3, 340, 341, 11],
#  [3, 340, 341, 11, 87]]

# %%
max_len=max([len(x) for x in input_sequence])

# %%
max_len
# Out:
# 9

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences=pad_sequences(input_sequence,maxlen=max_len,padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0, 102,   3],
#        [  0,   0,   0, ..., 102,   3,   2],
#        [  0,   0,   0, ...,   3,   2,   4],
#        ...,
#        [  0,   0,   0, ...,   3, 340, 341],
#        [  0,   0,   0, ..., 340, 341,  11],
#        [  0,   0,   0, ..., 341,  11,  87]], shape=(509, 9), dtype=int32)

# %%
X=padded_input_sequences[:,:-1]

# %%
y_=padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (509, 8)

# %%
y_.shape
# Out:
# (509,)

# %%
from tensorflow.keras.utils import to_categorical

y_=to_categorical(y_,num_classes=342)

# %%
y_.shape
# Out:
# (509, 342)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense
from tensorflow.keras import Input

# %%
model = Sequential([
    Input(shape=(9,)),
    Embedding(342, 100),
    LSTM(150),
    Dense(342, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 9, 100)         │        34,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 342)            │        51,642 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 236,442 (923.60 KB)
#  Trainable params: 236,442 (923.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 9, 100)         │        34,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 342)            │        51,642 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 236,442 (923.60 KB)
#  Trainable params: 236,442 (923.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y_,epochs=100)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0295 - loss: 5.8280
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0373 - loss: 5.6616
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0432 - loss: 5.4188
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0550 - loss: 5.3516
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0491 - loss: 5.3046
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0432 - loss: 5.2717
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0472 - loss: 5.2356
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0648 - loss: 5.1676
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0766 - loss: 5.0778
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0688 - loss: 4.9785
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0963 - loss: 4.8228
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1041 - loss: 4.6866
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1159 - loss: 4.5229
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1434 - loss: 4.3593
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1375 - loss: 4.1901
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1631 - loss: 4.0028
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2004 - loss: 3.8437
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2279 - loss: 3.6529
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2692 - loss: 3.4599
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3124 - loss: 3.2810
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3418 - loss: 3.1123
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3615 - loss: 2.9335
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4244 - loss: 2.7532
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4440 - loss: 2.5923
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5128 - loss: 2.4379
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5481 - loss: 2.2871
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6090 - loss: 2.1501
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6444 - loss: 2.0006
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6719 - loss: 1.8734
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7053 - loss: 1.7562
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7426 - loss: 1.6351
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7780 - loss: 1.5315
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7996 - loss: 1.4280
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8153 - loss: 1.3332
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8389 - loss: 1.2444
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8625 - loss: 1.1622
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8703 - loss: 1.0885
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8762 - loss: 1.0198
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8959 - loss: 0.9534
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9018 - loss: 0.8910
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9155 - loss: 0.8346
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9194 - loss: 0.7753
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9253 - loss: 0.7231
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9293 - loss: 0.6803
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9352 - loss: 0.6442
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9411 - loss: 0.6023
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9450 - loss: 0.5624
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9509 - loss: 0.5291
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9509 - loss: 0.4974
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9509 - loss: 0.4689
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9568 - loss: 0.4443
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9627 - loss: 0.4188
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9646 - loss: 0.3960
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9646 - loss: 0.3720
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9627 - loss: 0.3515
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9646 - loss: 0.3362
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9627 - loss: 0.3195
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9686 - loss: 0.3042
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9725 - loss: 0.2866
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9686 - loss: 0.2764
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9686 - loss: 0.2638
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9666 - loss: 0.2524
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9666 - loss: 0.2445
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9705 - loss: 0.2335
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9666 - loss: 0.2247
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9686 - loss: 0.2147
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9705 - loss: 0.2056
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9646 - loss: 0.2006
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9686 - loss: 0.1945
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9666 - loss: 0.1882
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9705 - loss: 0.1825
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9705 - loss: 0.1752
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9705 - loss: 0.1707
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9666 - loss: 0.1645
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9666 - loss: 0.1611
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9705 - loss: 0.1568
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9686 - loss: 0.1534
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9666 - loss: 0.1491
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9725 - loss: 0.1447
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9686 - loss: 0.1413
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9686 - loss: 0.1364
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9666 - loss: 0.1348
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9666 - loss: 0.1314
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9705 - loss: 0.1303
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9646 - loss: 0.1263
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9725 - loss: 0.1223
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9627 - loss: 0.1233
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9646 - loss: 0.1199
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9705 - loss: 0.1182
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9666 - loss: 0.1154
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9725 - loss: 0.1127
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9686 - loss: 0.1105
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9705 - loss: 0.1098
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9705 - loss: 0.1066
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9646 - loss: 0.1078
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9686 - loss: 0.1036
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9705 - loss: 0.1030
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9646 - loss: 0.1024
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9666 - loss: 0.1011
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9725 - loss: 0.0993

# %%
print(model.input_shape)
print(token_text)
print(padded_token_text.shape)
# Out:
# (None, 9)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 print(model.input_shape)
# ----> 2 print(token_text)
#       3 print(padded_token_text.shape)
#
# NameError: name 'token_text' is not defined

# %%
text = "training"

index_word = {v: k for k, v in tokenizer.word_index.items()}

for i in range(4):

    token_text = tokenizer.texts_to_sequences([text])[0]

    # Keep only last 9 tokens
    token_text = token_text[-9:]

    padded_token_text = pad_sequences(
        [token_text],
        maxlen=9,
        padding='pre'
    )

    prediction = model.predict(padded_token_text, verbose=0)

    pos = np.argmax(prediction[0])

    next_word = index_word.get(pos)

    if next_word is None:
        break

    text += " " + next_word

print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 20
#      12 padded_token_text = pad_sequences(
#      13     [token_text],
#      14     maxlen=9,
#      15     padding='pre'
#      16 )
#      18 prediction = model.predict(padded_token_text, verbose=0)
# ---> 20 pos = np.argmax(prediction[0])
#      22 next_word = index_word.get(pos)
#      24 if next_word is None:
#
# NameError: name 'np' is not defined

# %%
# text="training"

# token_text=tokenizer.texts_to_sequences([text])

# padded_token_text=pad_sequences([token_text],maxlen=9,padding='pre')
# pos=np.argmax(model.predict(padded_token_text))

# for word,index in tokenizer.word_index.items():
#     if index==pos:
#         print(word)

# %%
tokenizer.word_index

# %%
print(token_text)
print(padded_token_text.shape)
print(model.input_shape)
# Out:
# []
# (1, 9)
# (None, 9)

# %%
import numpy as np
